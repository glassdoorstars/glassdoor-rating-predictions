# %% [markdown]
# # STATS

# %%
import unicodedata
import re
import json
import wrangle as w
from nltk import *
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from scipy.stats import ttest_ind
import pandas as pd
from time import strftime
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import requests
from bs4 import BeautifulSoup
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import scipy.stats as stats
from scipy.stats import  chi2_contingency
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train, test, validate = w.wrangle_glassdoor()

# %%
train.head()
# Out:
#      Unnamed: 0                                                url  \
# 490         490  https://www.glassdoor.com/Reviews/Perficient-R...
# 273         273  https://www.glassdoor.com/Reviews/Farmers-Insu...
# 677          30  https://www.glassdoor.com/Reviews/MIT-Reviews-...
# 406         406  https://www.glassdoor.com/Reviews/Morningstar-...
# 953         163  https://www.glassdoor.com/Reviews/ICF-Reviews-...
#
#                                                   pros  \
# 490  Perficient is an ethical company that actually...
# 273  This company is the best ever.\nLarge, establi...
# 677  Very inspiring place to work at, to feel that ...
# 406  - Coworkers are amicable, and they're overall ...
# 953  Loved the job and the people. Great flexibilit...
#
#                                                   cons  \
# 490  None at all, love, love, love this company!\nI...
# 273  I have nothing bad to say.\nManagement company...
# 677  Depends on the project to how much organizatio...
# 406  - Base pay for the area could be slightly high...
# 953  None, I would fully recommend\nThere was disho...
#
#                         name  rating binned_rating binned_rating_int  \
# 490               Perficient     4.1          Four                 4
# 273  Farmers Insurance Group     3.4         Three                 3
# 677                      MIT     4.4          Four                 4
# 406              Morningstar     4.1          Four                 4
# 953                      ICF     3.8         Three                 3
#
#                                   pros_cleaned_content  \
# 490  perficient is an ethical company that actually...
# 273  this company is the best ever\nlarge establish...
# 677  very inspiring place to work at to feel that s...
# 406   coworkers are amicable and they're overall ve...
# 953  loved the job and the people great flexibility...
#
#                                        pros_lemmatized  \
# 490  perficient ethical company actually value empl...
# 273  company best ever large established company so...
# 677  inspiring place work feel something new happen...
# 406  coworkers amicable they're overall supportive ...
# 953  loved job people great flexibility fun project...
#
#                                   cons_cleaned_content  \
# 490  none at all love love love this company\nit is...
# 273  i have nothing bad to say\nmanagement company ...
# 677  depends on the project to how much organizatio...
# 406   base pay for the area could be slightly highe...
# 953  none i would fully recommend\nthere was dishon...
#
#                                        cons_lemmatized
# 490  none love love love company good company canno...
# 273  nothing bad say management company get paid re...
# 677  depends project much organization team include...
# 406  base pay area could slightly higher bonus prog...
# 953  none would fully recommend dishonest hidden in...

# %%
df = train

vectorizer = CountVectorizer()

X_train = vectorizer.fit_transform(df["pros"])

word_frequencies_df = pd.DataFrame(X_train.toarray(), columns=vectorizer.get_feature_names_out())

word_frequencies_total = word_frequencies_df.sum()

top_n = 80
top_words = word_frequencies_total.sort_values(ascending=False).index[:top_n]

for word in top_words:
    word_frequencies_by_language = {language: [] for language in df["binned_rating_int"].unique()}
    for index, row in df.iterrows():
        words = row["pros"].split()
        if word in words:
            word_frequencies_by_language[row["binned_rating_int"]].append(words.count(word))

    language_groups = [np.array(group) for group in language_groups]

# Perform the t-test
    statistic, p_value = ttest_ind(*language_groups)


    alpha = 0.05
    if p_value < alpha:
        print(f"Word: '{word}'")
        print("T-Test Statistic:", statistic)
        print("P-value:", p_value)
        print(f"There is a significant difference in word '{word}' frequencies among languages.\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 24
#      21     language_groups = [np.array(group) for group in language_groups]
#      23 # Perform the t-test
# ---> 24     statistic, p_value = ttest_ind(*language_groups)
#      27     alpha = 0.05
#      28     if p_value < alpha:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/scipy/stats/_stats_py.py:6809, in ttest_ind(a, b, axis, equal_var, nan_policy, permutations, random_state, alternative, trim)
#    6802     res = _permutation_ttest(a, b, permutations=permutations,
#    6803                              axis=axis, equal_var=equal_var,
#    6804                              nan_policy=nan_policy,
#    6805                              random_state=random_state,
#    6806                              alternative=alternative)
#    6808 else:
# -> 6809     n1 = a.shape[axis]
#    6810     n2 = b.shape[axis]
#    6812     if trim == 0:
#
# TypeError: only integer scalar arrays can be converted to a scalar index
