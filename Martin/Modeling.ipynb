# %%
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

import wrangle as w
import model as m

import pandas as pd

# %%
train, validate, test = w.wrangle_glassdoor('../data/glassdoor_reviews.csv')

# %%
train = train[train['binned_rating_int'] !=2 ]

# %%
X_train, y_train, X_validate,\
    y_validate, X_test, y_test = m.X_y_split(train, validate, test, 'binned_rating_int')

# %%
X_train
# Out:
#                                                    url  \
# 490  https://www.glassdoor.com/Reviews/Perficient-R...
# 273  https://www.glassdoor.com/Reviews/Farmers-Insu...
# 30   https://www.glassdoor.com/Reviews/MIT-Reviews-...
# 406  https://www.glassdoor.com/Reviews/Morningstar-...
# 163  https://www.glassdoor.com/Reviews/ICF-Reviews-...
# ..                                                 ...
# 94   https://www.glassdoor.com/Reviews/Dignity-Heal...
# 303  https://www.glassdoor.com/Reviews/Ace-Hardware...
# 4    https://www.glassdoor.com/Reviews/Chick-fil-A-...
# 233  https://www.glassdoor.com/Reviews/Foundever-Re...
# 152  https://www.glassdoor.com/Reviews/Progressive-...
#
#                                                   pros  \
# 490  Perficient is an ethical company that actually...
# 273  This company is the best ever.\nLarge, establi...
# 30   Very inspiring place to work at, to feel that ...
# 406  - Coworkers are amicable, and they're overall ...
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
feature_column = 'cons_lemmatized'
X_train = X_train[feature_column]
X_validate = X_validate[feature_column]

tfidf = TfidfVectorizer()

#fit and transform the vectorizer
X_train = tfidf.fit_transform(X_train)
X_validate = tfidf.transform(X_validate)

# %%
pd.DataFrame(bag_of_words.todense(), 
             columns=tfidf.get_feature_names_out())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pd.DataFrame(bag_of_words.todense(),
#       2              columns=tfidf.get_feature_names_out())
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Baseline: `sklearn.dummy.DummyClassifier`

# %%
# Make Dummy classifier
clf = DummyClassifier(strategy='most_frequent').fit(X_train, y_train)
